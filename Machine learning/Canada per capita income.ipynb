# %% [markdown]
# ### Predict canada's per capita income in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income fo canadian citizens in year 2020,2021,2022

# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',500)
pd.set_option('display.max_rows',100)
pd.set_option('display.width',500)

# %%
# Import the csv file 
df=pd.read_csv('per_capita_income.csv')
df
# Out:
#     year  per_capita_income
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
df.head()
# Out:
#    year  per_capita_income
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484
# 3  1973        4804.463248
# 4  1974        5576.514583

# %%
df.head()
# Out:
#    year  per_capita_income
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484
# 3  1973        4804.463248
# 4  1974        5576.514583

# %%
# Creating the plot using matplotlib
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per_capita_income')
plt.scatter(df.year,df.per_capita_income,color='red',marker='+')

# %%
new_df=df.drop('per_capita_income',axis='columns')
new_df.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
income=df.per_capita_income  # Equating the income with the dataframe

# %% [markdown]
# ## Using Linear Regression model

# %%
# Create a linearRegression object
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
reg= linear_model.LinearRegression()
reg.fit(new_df,income)
# Out:
# LinearRegression()

# %%
p=reg.predict(new_df)
p
# Out:
# array([ -134.55966672,   693.9054085 ,  1522.37048373,  2350.83555895,
#         3179.30063417,  4007.7657094 ,  4836.23078462,  5664.69585984,
#         6493.16093506,  7321.62601029,  8150.09108551,  8978.55616073,
#         9807.02123595, 10635.48631118, 11463.9513864 , 12292.41646162,
#        13120.88153685, 13949.34661207, 14777.81168729, 15606.27676251,
#        16434.74183774, 17263.20691296, 18091.67198818, 18920.1370634 ,
#        19748.60213863, 20577.06721385, 21405.53228907, 22233.9973643 ,
#        23062.46243952, 23890.92751474, 24719.39258996, 25547.85766519,
#        26376.32274041, 27204.78781563, 28033.25289085, 28861.71796608,
#        29690.1830413 , 30518.64811652, 31347.11319175, 32175.57826697,
#        33004.04334219, 33832.50841741, 34660.97349264, 35489.43856786,
#        36317.90364308, 37146.3687183 , 37974.83379353])

# %%
reg.coef_ # c=mx+y where m is coef , x is prediction slope, and y is the intercept
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# -1632210.7578554575

# %%
828.46507522*2020+-1632210.7578554575   # x=2020
# Out:
# 41288.694088942604

# %%
 # Import another csv file to predict the remaining years income 
DataFrame=pd.read_csv('years_income.csv')
DataFrame   # Here the values of per_capita_income is wrong the actual predicted value is correct for particular year as per model
# Out:
#     Unnamed: 0  year  per_capita_income
# 0            0  2016        -134.559667
# 1            1  2017         693.905409
# 2            2  2018        1522.370484
# 3            3  2019        2350.835559
# 4            4  2020        3179.300634
# 5            5  2021        4007.765709
# 6            6  2022        4836.230785
# 7            7  2023        5664.695860
# 8            8  2024        6493.160935
# 9            9  2025        7321.626010
# 10          10  2026        8150.091086
# 11          11  2027        8978.556161
# 12          12  2028        9807.021236
# 13          13  2029       10635.486311
# 14          14  2030       11463.951386
# 15          15  2031       12292.416462
# 16          16  2032       13120.881537
# 17          17  2033       13949.346612
# 18          18  2034       14777.811687
# 19          19  2035       15606.276763
# 20          20  2036       16434.741838
# 21          21  2037       17263.206913
# ...

# %%
new_f=DataFrame.drop(columns=['Unnamed: 0','per_capita_income'])
new_f.head()
# Out:
#    year
# 0  2016
# 1  2017
# 2  2018
# 3  2019
# 4  2020

# %%
model=reg.predict(new_f)
model
# Out:
# array([37974.83379353, 38803.29886875, 39631.76394397, 40460.22901919,
#        41288.69409442, 42117.15916964, 42945.62424486, 43774.08932009,
#        44602.55439531, 45431.01947053, 46259.48454575, 47087.94962098,
#        47916.4146962 , 48744.87977142, 49573.34484664, 50401.80992187,
#        51230.27499709, 52058.74007231, 52887.20514754, 53715.67022276,
#        54544.13529798, 55372.6003732 , 56201.06544843, 57029.53052365,
#        57857.99559887, 58686.46067409, 59514.92574932, 60343.39082454,
#        61171.85589976, 62000.32097499, 62828.78605021, 63657.25112543,
#        64485.71620065, 65314.18127588, 66142.6463511 , 66971.11142632,
#        67799.57650154, 68628.04157677, 69456.50665199, 70284.97172721,
#        71113.43680244, 71941.90187766, 72770.36695288, 73598.8320281 ,
#        74427.29710333, 75255.76217855, 76084.22725377])
