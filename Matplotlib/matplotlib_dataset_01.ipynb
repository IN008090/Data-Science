# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,45]

# %%
plt.plot(x,y,'g+')  # This argument defined the key points in graphs

# %%
plt.plot(x,y,'g+--')  # These argumentpresent the key point along with line

# %%
plt.plot(x,y,'--b') # There are multiple argument can check on matplot API doc.
