# %% [markdown]
# ## Architecture For Machine Learning Model

# %% [markdown]
# ![Model_Art.jpeg](attachment:Model_Art.jpeg)

# %% [markdown]
# ## Data
#
# + Incorrect, incomplete, irrelevant, duplicated, or improperly formatted.
# + Fixing spelling and syntax errors,Standardizing data sets,Correcting mistakes such as empty fields,Identifying duplicate data points.

# %% [markdown]
# ![step_2.JPG](attachment:step_2.JPG)

# %% [markdown]
# ## How to Clean Your Data
#
# +  Remove duplicate observations
# +  Filter unwanted outliers
# +  Fix structural errors
# +  Fix missing data
# +  Validate your data
# +  Data Prep Checklist: The Basics

# %% [markdown]
# ### Data Prep Checklist: The Basics
#
# + Dataset must have at least 1,000 rows
# + Dataset must have at least 5 columns
# + The first column must be an identifier column, such as a name, customer_id, etc.
# + The first row should be column names
# + The data should be aggregated in a single file or table
# + The data must have as less missing values as possible
# + No personally identifiable information is required, such as phone numbers, addresses, etc.
# + No long text phrases—only use discrete values for text columns
# + The column names must not contain space in between.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# List of Techniques
# +  Imputation
# +  Handling Outliers
# +  Binning
# +  Log Transform
# +  One-Hot Encoding
# +  Grouping Operations
# +  Feature Split
# +  Scaling
# +  Extracting Date

# %% [markdown]
# ## Imputation
# +  Drop the rows and columns which have missing values with higher than this threshold.
#
# ![Step3.JPG](attachment:Step3.JPG)

# %% [markdown]
# ## Numerical Imputation
#
# ![sTEP4.JPG](attachment:sTEP4.JPG)

# %% [markdown]
# ## Categorical Imputation
#
# ![STEP_6.JPG](attachment:STEP_6.JPG)

# %% [markdown]
# ##  Handling Outliers
# ### Outlier Detection with Standard Deviation
#
# ![STEP7.JPG](attachment:STEP7.JPG)

# %% [markdown]
# ## Outlier Detection with Percentiles
#
# ![sTEP8.JPG](attachment:sTEP8.JPG)

# %% [markdown]
#  ## An Outlier Dilemma: Drop or Cap
#
#  ![sTEP9.JPG](attachment:sTEP9.JPG)

# %% [markdown]
# ## Binning
#
# ![STP10.JPG](attachment:STP10.JPG)
#
# ### The binning is to make the model more robust and prevent overfitting, however, it has a cost to the performance.

# %% [markdown]
# ### Log Transform
#
# ![sTEP11.JPG](attachment:sTEP11.JPG)

# %% [markdown]
# ## One-hot encoding
#
# ![STEP12.JPG](attachment:STEP12.JPG)

# %% [markdown]
# ![STEP13.JPG](attachment:STEP13.JPG)

# %% [markdown]
# ###  Categorical Column Grouping
#
# ![SNIPP01.JPG](attachment:SNIPP01.JPG)

# %% [markdown]
# ![SNIPP00.JPG](attachment:SNIPP00.JPG)

# %% [markdown]
# ## Numerical Column Grouping
#
# ![SNIPP03.JPG](attachment:SNIPP03.JPG)

# %% [markdown]
# ## Feature Split
#
#  ## Split
# ![sNIPP04.JPG](attachment:sNIPP04.JPG)

# %% [markdown]
# ![snipp05.JPG](attachment:snipp05.JPG)

# %% [markdown]
# ##  Scaling
#
# ![Snipp06.JPG](attachment:Snipp06.JPG)

# %% [markdown]
# ![Snipp07.JPG](attachment:Snipp07.JPG)

# %% [markdown]
# ## Standardization
#
# ![Snipp20.JPG](attachment:Snipp20.JPG)

# %% [markdown]
# ## Extracting Date
#
# ![snippp.JPG](attachment:snippp.JPG)
